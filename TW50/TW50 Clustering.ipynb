# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
from sklearn.manifold import MDS
from matplotlib.font_manager import FontProperties
from sklearn import manifold
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sqlite3
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
# %matplotlib inline
plt.rcParams['axes.unicode_minus']=False
engine = create_engine('sqlite:///tw50.db')

# %% [markdown]
# # 技術分析做K-means

# %%
link = []
for i in range(3):
    html = urlopen("https://www.cnyes.com/twstock/index2real.aspx?PageIndex="+str(i+1)+
                   "&itype=TW50&stitle=%u81fa%u7063%u4e94%u5341%u6307%u6578%u6210%u4efd%u80a1")
    soup = BeautifulSoup(html,"lxml")
    soup = soup.find('div',{'class':'mbx screenBx'})
    soup = soup.findAll('tr')
    for row in soup[2:]:
        link.append('https://www.cnyes.com'+ row.find('a').get('href'))

# %%
data = np.zeros([50,29], dtype=float)
name = []
for i,row in enumerate(link):
    html = urlopen('https://www.cnyes.com/twstock/Technical/' + row[-8:])
    soup = BeautifulSoup(html,"lxml")
    temp_name = soup.find('span',{'id':'ctl00_ContentPlaceHolder1_titleLab'})
    name.append(temp_name.text.split(' ')[0])
    soup = soup.find('div',{'class':'tab'})
    soup = soup.findAll('table')
    temp_data = []
    for j in soup:
        temp = j.findAll('tr')[1]
        temp = temp.findAll('td',{'class':'rt'})
        for k in temp:
            temp_data.append(float(k.getText()))
    data[i] = temp_data

# %%
data = pd.DataFrame(data,index=name , columns=['收盤價','3日均價','5日均價','10日均價','20日均價','60日均價','120日均價','240日均價',
                           '成交張數','3日均量','5日均量','10日均量','20日均量','60日均量','120日均量','240日均量',
                           '6日rsi','9日 k值','9日 d值','12日 obv','26日 ar值','26日 br值','26日 vr值','72日bias',
                           '3-6乖離率','10日 mtm','9日威廉','tapi','12日心理線'])

# %%
data
# Out:
#            收盤價     3日均價     5日均價    10日均價    20日均價    60日均價   120日均價   240日均價  \
# 台泥       35.75    35.40    35.15    35.12    35.05    36.63    39.16    39.31
# 亞泥       34.00    33.55    33.32    33.54    33.26    35.30    37.41    33.94
# 統一       68.90    69.53    69.14    69.53    71.64    74.12    75.65    72.83
# 臺塑       99.20    99.10    99.06   100.03   100.18   103.94   107.39   105.81
# 南亞       73.00    72.80    72.70    73.15    74.64    77.54    81.04    81.52
# 台化      105.00   105.33   105.10   105.70   106.03   112.33   115.54   112.71
# 遠東新      28.15    28.40    28.50    28.57    28.66    31.32    32.21    29.64
# 中鋼       24.15    24.27    24.11    24.14    24.07    24.39    24.46    24.22
# 正新       42.90    42.48    42.00    42.27    41.49    43.02    44.73    46.65
# 光寶科      40.45    40.57    40.63    40.87    39.91    37.72    37.50    38.83
# 聯電       11.35    11.38    11.25    11.38    11.37    12.54    14.87    15.12
# 台達電     131.50   130.33   129.10   128.95   127.20   124.78   116.89   122.22
# 鴻海       71.50    71.90    70.36    70.89    71.13    74.13    78.02    83.44
# 國巨      320.00   324.33   325.70   353.10   345.73   371.87   573.74   586.96
# 台積電     222.50   225.00   223.30   225.25   223.85   234.53   237.86   238.02
# 鴻準       60.90    61.07    60.80    61.58    61.59    65.85    70.84    74.95
# 華碩      207.00   211.67   212.80   215.00   216.50   231.44   245.26   260.61
# 廣達       50.80    50.80    50.27    49.95    49.60    49.78    51.16    54.63
# 台塑化     -0.17    -4.50   77.78    20461.33    0.50
# 寶成     -31.25    -2.25   66.67   163707.50    0.58
#
# [50 rows x 29 columns]

# %%
kmeans = KMeans(n_clusters=4, random_state=0, n_jobs=4, max_iter=1000, n_init=3).fit(data)

# %%
temp = {}
for i in range(50):
    temp[name[i]] = kmeans.labels_[i]

# %%
data['label'] = data.index.map(temp)

# %% [markdown]
# # 結果

# %%
data.sort_values('label')['label']
# Out:
# 華新科      0
# 中華電      0
# 聯發科      0
# 可成       0
# 台塑化      0
# 台灣高鐵     0
# 彰銀       0
# 中壽       0
# 富邦金      0
# 統一超      0
# 大立光      0
# 台灣大      0
# 日月光投控    0
# 遠傳       0
# 和碩       0
# 中租-KY    0
# 南亞科      0
# 研華       0
# 寶成       0
# 華碩       0
# 南亞       0
# 廣達       0
# 臺塑       0
# 統一       0
# 光寶科      0
# 正新       0
# 國巨       0
# 台積電      0
# 鴻準       0
# 台達電      0
# 台化       0
# 群創       1
# 開發金      1
# 元大金      1
# 台新金      1
# 永豐金      1
# 中信金      1
# 友達       1
# 聯電       2
# 合庫金      3
# 亞泥       3
# 兆豐金      3
# 中鋼       3
# 第一金      3
# 玉山金      3
# 國泰金      3
# 華南金      3
# 鴻海       3
# 遠東新      3
# 台泥       3
# Name: label, dtype: int64

# %% [markdown]
# # 均價加報酬率做K-means

# %%
data = pd.read_csv('50.csv',index_col='證券代碼')

# %%
data = data.drop('日期',axis=1)

# %%
data
# Out:
#             3日均價(元)  5日均價(元)  10日均價(元)  13日均價(元)  15日均價(元)  20日均價(元)  \
# 證券代碼
# 1101 台泥       36.28    36.28     35.42     35.11     34.96     34.69
# 1102 亞泥       27.75    27.56     27.23     27.14     27.05     26.96
# 1216 統一       65.80    65.42     65.25     65.45     65.34     65.08
# 1301 台塑       98.03    97.22     96.07     95.49     95.17     94.68
# 1303 南亞       77.53    77.12     76.40     76.02     75.78     75.61
# 1326 台化      101.50   100.08     99.07     98.12     97.57     96.92
# 1402 遠東新      26.35    26.18     25.93     25.85     25.79     25.71
# 2002 中鋼       24.67    24.55     24.41     24.37     24.37     24.41
# 2105 正新       51.83    51.38     51.24     51.18     51.17     51.37
# 2301 光寶科      40.38    40.19     39.95     39.68     39.45     39.00
# 2303 聯電       14.23    14.24     14.37     14.47     14.54     14.69
# 2308 台達電     141.67   141.00    139.20    138.77    138.63    138.58
# 2317 鴻海       93.90    93.00     92.77     93.06     93.33     93.74
# 2327 國巨      343.33   339.20    339.05    330.96    326.20    318.53
# 2330 台積電     226.83   227.00    226.40    227.04    227.10    227.53
# 2354 鴻準       84.23    83.82     84.26     84.56     84.77     84.68
# 2357 華碩      276.67   274.80    273.70    272.62    272.13    271.20
# 2382 廣達       61.57    61.46     61.35     61.42     61.31     61.03
# 2395 研華      208.83   208.70    209.20    207.77    207.07    205.30
# 2408 南亞科      75.50    75.36     77.27     77.38     77.39     76.62
# 2409 友達       12.42    12.41     12.40     12.45     12.47     12.49
# 2412 中華電     105.83   105.80    105.50    105.38    105.27    105.00
# 2454 聯發科     287.67   286.00    288.45    288.46    289.70    292.68
# 2474 可成      325.67   324.30    326.80    325.08    324.33    323.20
# 2880 華南金         1.5151     12.5902
# 2881 富邦金         7.4152      3.6555
# 2882 國泰金        10.9958     15.5642
# 2883 開發金        11.4159     33.4446
# 2884 玉山金         4.1325     14.7401
# 2885 元大金         5.3438     18.8868
# 2886 兆豐金         1.2632     10.7784
# 2887 台新金         6.1302     27.1796
# 2890 永豐金         6.4975     14.2373
# 2891 中信金         7.3301     21.9835
# 2892 第一金        -0.0002     22.9491
# 2912 統一超        11.5918     26.7714
# 3008 大立光   -252091.0000  72846.0000
# 3045 台灣大        -0.9218      8.7752
# 3481 群創        -12.3673      7.5744
# 4904 遠傳          1.2400      6.5515
# 4938 和碩         -9.5480     -1.6267
# 5871 中租-KY      15.7757     63.3318
# 5880 合庫金         6.0705     27.4485
# 6505 台塑化         8.9623      9.0177
# 9904 寶成          1.4476     -0.6748

# %%
kmeans = KMeans(n_clusters=4, random_state=0, n_jobs=4, max_iter=1000, n_init=3).fit(data)

# %%
temp = {}
for j,i in enumerate(data.index):
    temp[i] = kmeans.labels_[j]

# %%
data = data.drop(index='3008 大立光')

# %%
data['label'] = data.index.map(temp)

# %% [markdown]
# # 結果

# %%
data.sort_values('label')['label']
# Out:
# 證券代碼
# 2354 鴻準       0
# 2412 中華電      0
# 2317 鴻海       0
# 2308 台達電      0
# 3045 台灣大      0
# 6505 台塑化      0
# 2408 南亞科      0
# 4904 遠傳       0
# 5871 中租-KY    0
# 1326 台化       0
# 1303 南亞       0
# 1301 台塑       0
# 1216 統一       0
# 2492 華新科      0
# 4938 和碩       0
# 2382 廣達       0
# 2454 聯發科      2
# 2912 統一超      2
# 2474 可成       2
# 2357 華碩       2
# 2330 台積電      2
# 2327 國巨       2
# 2395 研華       2
# 2885 元大金      3
# 3481 群創       3
# 5880 合庫金      3
# 2892 第一金      3
# 2891 中信金      3
# 2890 永豐金      3
# 2887 台新金      3
# 2886 兆豐金      3
# 2884 玉山金      3
# 1101 台泥       3
# 2882 國泰金      3
# 2881 富邦金      3
# 2880 華南金      3
# 2823 中壽       3
# 2801 彰銀       3
# 2633 台灣高鐵     3
# 2409 友達       3
# 2303 聯電       3
# 2301 光寶科      3
# 2105 正新       3
# 2002 中鋼       3
# 1402 遠東新      3
# 1102 亞泥       3
# 2883 開發金      3
# 9904 寶成       3
# Name: label, dtype: int64

# %% [markdown]
# # 一年每週價格漲跌幅做K-means

# %%
conn = sqlite3.connect('tw50.db')
c = conn.cursor()

# %%
names = []
cursor = c.execute("SELECT DISTINCT id FROM price")
for row in cursor:
    names.append(row[0])

names.remove('5871 中租-KY')
names.remove('5880 合庫金')

# %%
rate = []
for name in names:
    cursor = c.execute("SELECT price FROM price WHERE id = ?  AND date >= ? ORDER BY date ASC LIMIT 53",[name,'2010-12-03'])

    price = []
    for row in cursor:
        price.append(row[0])
    
    temp = []
    for i in range(len(price)):
        if i == 0:
            continue
        temp.append((price[i]-price[i-1])/price[i-1])
    rate.append(temp)

# %%
distance = []
for i in rate:
    temp = []
    for j in rate:
        corr= np.corrcoef(i,j)
        corr = corr[0][-1]
        if i == j:
            corr = 1
        temp.append(1-(corr*0.5+0.5))
    distance.append(temp)

# %%
mds = manifold.MDS(n_jobs=3,random_state=1,dissimilarity="precomputed")
pos = mds.fit(distance).embedding_

clf = KMeans(n_clusters=4,verbose=1)
clf.fit(rate)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.147829517371617
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.135361589070384
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.135361589070384
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.0017480831595362
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 2.974504829316855
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 2.946476400151159
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 2.8926621450404912
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 2.8926621450404912
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.0797479476171494
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.039959907256864
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.039959907256864
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.1641006548772
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.1641006548772
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.433857360789682
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.1701921245912916
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.099889537669904
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3.0581397484117137
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3.0501363203580434
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3.0501363203580434
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.013910377923055
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 2.970308845758929
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 2.970308845758929
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.2390867680144924
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.118006782332788
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.1139370410561673
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3.1139370410561673
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.078633656746115
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.0605343072596938
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.0605343072596938
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.2377695340334975
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.119893153629289
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.0570425291274264
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3.048557047193902
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3.048557047193902
# center shift 0.000000e+00 within tolerance 1.628043e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3.3057284044092743
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3.190054066149675
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3.1361612767853515
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3.0652988471183837
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3.0373982020027865
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3.027544893936085
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3.027544893936085
# center shift 0.000000e+00 within tolerance 1.628043e-07
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=1)

# %% [markdown]
# # 結果

# %%
plt.figure(figsize=(15, 15))
plt.subplots_adjust(bottom=0.1)  
plt.scatter(pos[:, 0], pos[:, 1], c=clf.labels_)
# for i,name in enumerate(names):
#     names[i] = name.split(' ')[1]
for label, x, y in zip(names, pos[:, 0], pos[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-3, 3),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
year = '2006'
remuneration0 = []
remuneration1 = []

for i in range(6):
    temp = year+'-01-01'
    data0 = pd.read_sql('select * from price where (id = "2408 南亞科" or id = "2886 兆豐金" or id = "2330 台積電" or id = "2474 可成") and date > ? ORDER BY date ASC LIMIT 3',con=engine,index_col='id',params=[temp])
    data00 = pd.read_sql('select * from price where id = "0050 元大台灣50" and date > ? ORDER BY date ASC LIMIT 1',con=engine,index_col='id',params=[temp])
#     print(data00)
    temp = year+'-12-31'
    data1 = pd.read_sql('select * from price where (id = "2408 南亞科" or id = "2886 兆豐金" or id = "2330 台積電" or id = "2474 可成") and date < ? ORDER BY date DESC LIMIT 3',con=engine,index_col='id',params=[temp])
    data01 = pd.read_sql('select * from price where id = "0050 元大台灣50" and date < ? ORDER BY date DESC LIMIT 1',con=engine,index_col='id',params=[temp])
#     print(data01)
    temp = (data1['price_adjustment'] - data0['price_adjustment'])/data0['price_adjustment']
    remuneration0.append(temp.describe()['mean']*100)
    temp = (data01['price_adjustment'] - data00['price_adjustment'])/data00['price_adjustment']
    remuneration1.append(temp.values[0]*100)
    year = str(int(year)+1)

# %%
index = [2006,2007,2008,2009,2010,2011]
index = np.asarray(index)
plt.bar(index,remuneration0,.2,facecolor = 'yellowgreen', label='choose')
plt.bar(index+0.25,remuneration1,.2,facecolor = 'lightskyblue', label='0050')
for x,y in zip(index,remuneration0):
    plt.text(x, y+0.08, '%.2f' % y, ha='center', va= 'bottom')
for x,y in zip(index,remuneration1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
plt.grid(True)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 一年每週價格漲跌幅做Hierarchical

# %%
plt.figure(figsize=(10, 7))   
dend = shc.dendrogram(shc.linkage(pos, method='ward'))

# %%
cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
cluster.fit(pos)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=4,
#             pooling_func=<function mean at 0x7f8704289e18>)

# %% [markdown]
# # 結果

# %%
plt.figure(figsize=(13, 13))
plt.scatter(pos[:,0], pos[:,1], c=cluster.labels_, cmap='rainbow')
for label, x, y in zip(names, pos[:, 0], pos[:, 1]):  
    plt.annotate(
        label,
        xy=(x, y), xytext=(-3, 3),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
year = '2006'
remuneration0 = []
remuneration1 = []

for i in range(6):
    temp = year+'-01-01'
    data0 = pd.read_sql('select * from price where (id = "2409 友達" or id = "2881 富邦金" or id = "2308 台達電" or id = "9904 寶成") and date > ? ORDER BY date ASC LIMIT 3',con=engine,index_col='id',params=[temp])
    data00 = pd.read_sql('select * from price where id = "0050 元大台灣50" and date > ? ORDER BY date ASC LIMIT 1',con=engine,index_col='id',params=[temp])
#     print(data00)
    temp = year+'-12-31'
    data1 = pd.read_sql('select * from price where (id = "2409 友達" or id = "2881 富邦金" or id = "2308 台達電" or id = "9904 寶成") and date < ? ORDER BY date DESC LIMIT 3',con=engine,index_col='id',params=[temp])
    data01 = pd.read_sql('select * from price where id = "0050 元大台灣50" and date < ? ORDER BY date DESC LIMIT 1',con=engine,index_col='id',params=[temp])
#     print(data01)
    temp = (data1['price_adjustment'] - data0['price_adjustment'])/data0['price_adjustment']
    remuneration0.append(temp.describe()['mean']*100)
    temp = (data01['price_adjustment'] - data00['price_adjustment'])/data00['price_adjustment']
    remuneration1.append(temp.values[0]*100)
    year = str(int(year)+1)

# %%
index = [2006,2007,2008,2009,2010,2011]
index = np.asarray(index)
plt.bar(index,remuneration0,.2,facecolor = 'yellowgreen', label='選擇')
plt.bar(index+0.25,remuneration1,.2,facecolor = 'lightskyblue', label='0050')
for x,y in zip(index,remuneration0):
    plt.text(x, y+0.08, '%.2f' % y, ha='center', va= 'bottom')
for x,y in zip(index,remuneration1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
plt.grid(True)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 價量關係做k-means

# %%
data = pd.read_csv('50價量.csv',index_col='證券代碼')
data = data.drop('收盤價(元)_週',axis=1)
data = data.drop(index=['2327 國巨','2492 華新科'])

# %%
data = data[data['年月日'] < '2016-12-31']

# %%
data =  data[data['年月日'] > '2016-01-01']

# %%
data = data.drop('年月日',axis=1)

# %%
num_price = []
for i in data.index[:47]:
    temp = data.loc[i].values
    temp = temp.reshape(102)
    num_price.append(temp)

# %%
kmeans = KMeans(n_clusters=4, random_state=0, n_jobs=4, max_iter=1000, n_init=3).fit(num_price)

# %%
kmeans.cluster_centers_
# Out:
# array([[4.04796452e+04, 1.42690323e+02, 3.84859032e+04, 1.43977419e+02,
#         3.45868387e+04, 1.42627419e+02, 3.71148710e+04, 1.62916129e+02,
#         1.80952258e+04, 1.56214516e+02, 3.12995484e+04, 1.65356452e+02,
#         2.72910323e+04, 1.67054839e+02, 2.86222581e+04, 1.76150000e+02,
#         3.15386129e+04, 1.71982258e+02, 3.83771613e+04, 1.72740323e+02,
#         2.44086129e+04, 1.67470968e+02, 2.99023871e+04, 1.68582258e+02,
#         1.98343226e+04, 1.64838710e+02, 2.89797419e+04, 1.68082258e+02,
#         1.24052200e+05, 5.58600000e+01, 1.43650200e+05, 5.65200000e+01,
#         1.27041800e+05, 5.54600000e+01, 1.51200600e+05, 5.32300000e+01,
#         1.64504200e+05, 5.18900000e+01, 1.74584000e+05, 5.12000000e+01,
#         1.43658800e+05, 5.21100000e+01, 1.49248400e+05, 5.49500000e+01,
#         2.57359800e+05, 5.60500000e+01, 1.08111200e+05, 5.74300000e+01,
#         2.00382800e+05, 5.62500000e+01, 1.80841600e+05, 5.58100000e+01,
#         1.46936200e+05, 5.77100000e+01, 1.21402800e+05, 5.73300000e+01,
#         2.65011400e+05, 5.90500000e+01, 1.94350800e+05, 6.00100000e+01,
#         2.40871200e+05, 6.02200000e+01, 1.31584600e+05, 6.12400000e+01,
#         1.77490800e+05, 6.11200000e+01, 2.24542400e+05, 6.03400000e+01,
#         1.58471400e+05, 6.15400000e+01, 1.93217400e+05, 5.85700000e+01,
#         1.56380800e+05, 5.94300000e+01, 9.87152000e+04, 5.82300000e+01,
#         1.37729200e+05, 6.17800000e+01, 9.06760000e+04, 6.04900000e+01,
#         8.47516000e+04, 6.18200000e+01, 1.34535400e+05, 6.18300000e+01,
#         1.39008000e+05, 6.27100000e+01, 1.19914200e+05, 6.29800000e+01,
#         1.12354800e+05, 6.13200000e+01, 1.64641400e+05, 6.00300000e+01,
#         1.53643000e+05, 6.03400000e+01, 1.01483400e+05, 6.05700000e+01,
#         1.63888400e+05, 6.00300000e+01, 1.60238200e+05, 6.24700000e+01,
#         1.55588200e+05, 6.19800000e+01, 1.10305200e+05, 6.03300000e+01,
#         9.32254000e+04, 6.13500000e+01]])

# %%
na_pr = pd.DataFrame(data=list(data.index[:47]),columns=['name'])

# %%
temp = {}
for i in range(47):
    temp[i] = kmeans.labels_[i]

# %%
na_pr['label'] = na_pr.index.map(temp)

# %% [markdown]
# # 結果

# %%
na_pr.sort_values('label')
# Out:
#            name  label
# 0       1101 台泥      0
# 20     2412 中華電      0
# 21     2454 聯發科      0
# 22      2474 可成      0
# 45      9904 寶成      0
# 24      2823 中壽      0
# 25     2880 華南金      0
# 18     2408 南亞科      0
# 36     2912 統一超      0
# 38     3045 台灣大      0
# 40      4904 遠傳      0
# 41      4938 和碩      0
# 42   5871 中租-KY      0
# 43     5880 合庫金      0
# 44     6505 台塑化      0
# 37     3008 大立光      0
# 17      2395 研華      0
# 23      2801 彰銀      0
# 15      2357 華碩      0
# 1       1102 亞泥      0
# 2       1216 統一      0
# 3       1301 台塑      0
# 4       1303 南亞      0
# 5       1326 台化      0
# 6      1402 遠東新      0
# 8       2105 正新      0
# 16      2382 廣達      0
# 46  0050 元大台灣50      0
# 14      2354 鴻準      0
# 11     2308 台達電      0
# 9      2301 光寶科      0
# 28     2883 開發金      1
# 27     2882 國泰金      1
# 35     2892 第一金      1
# 7       2002 中鋼      1
# 33     2890 永豐金      1
# 26     2881 富邦金      1
# 31     2886 兆豐金      1
# 29     2884 玉山金      1
# 32     2887 台新金      1
# 39      3481 群創      2
# 19      2409 友達      2
# 10      2303 聯電      3
# 30     2885 元大金      3
# 12      2317 鴻海      3
# 13     2330 台積電      3
# 34     2891 中信金      3
